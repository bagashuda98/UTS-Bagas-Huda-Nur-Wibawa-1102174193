# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
ls
# Out:
# 3Scene/                  data_cancer.csv                Untitled0.ipynb
# classify_iris_ANN.ipynb  scene_dataset_using_ANN.ipynb

# %%
# import the necessary packages
from keras.models import Sequential
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.optimizers import Adam
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from PIL import Image
from imutils import paths
import numpy as np
import os

# %%
# grab all image paths in the input dataset directory, then initialize
# our list of images and corresponding class labels
print("[INFO] loading images...")
imagePaths = paths.list_images("3Scene")
data = []
labels = []
# Out:
# [INFO] loading images...

# %%
# loop over our input images
for imagePath in imagePaths:
	# load the input image from disk, resize it to 64x64 pixels, scale
	# the pixel intensities to the range [0, 1], and then update our
	# images list
	image = Image.open(imagePath)
 #bisa pasang preprocessing disini jika mau, seperti filterring, dll
	image = np.array(image.resize((64, 64))) / 255.0 #normalisasi
	data.append(image)

	# extract the class label from the file path and update the
	# labels list
	label = imagePath.split(os.path.sep)[-2]
	labels.append(label)

# %%
print(labels)
# Out:
# ['forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', ...

# %%
# encode the labels, converting them from strings to integers
lb = LabelBinarizer()
labels = lb.fit_transform(labels)

# %%
print(labels)
# Out:
# [[0 1 0]
#  [0 1 0]
#  [0 1 0]
#  ...
#  [0 0 1]
#  [0 0 1]
#  [0 0 1]]

# %%
print(np.array(data).shape)
# Out:
# (948, 64, 64, 3)

# %%
# perform a training and testing split, using 75% of the data for
# training and 25% for evaluation
(trainX, testX, trainY, testY) = train_test_split(np.array(data),	np.array(labels), test_size=0.25)
print(trainX.shape)
print(testX.shape)
# Out:
# (711, 64, 64, 3)
# (237, 64, 64, 3)

# %%
from keras.models import Sequential
from keras.layers.core import Flatten
from keras.layers.core import Dense, Dropout

model = Sequential(
    [
        Flatten(input_shape=(64*64*3,)), 
        Dense(512, activation="relu"),  
        Dropout(0.2),
        Dense(256, activation="relu"),
        Dense(128, activation="relu"),
        Dropout(0.3),
        Dense(64, activation="relu"),
        Dense(32, activation="relu"),
        Dropout(0.4),
        Dense(32, activation="relu"),
        Dense(16, activation="relu"),
        Dense(3, activation = "softmax"),
    ]
)

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_5 (Flatten)          (None, 12288)             0
# _________________________________________________________________
# dense_40 (Dense)             (None, 512)               6291968
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_41 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_42 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_43 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_44 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_45 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_46 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_47 (Dense)             (None, 3)                 51
# =================================================================
# Total params: 6,468,163
# Trainable params: 6,468,163
# Non-trainable params: 0
# _________________________________________________________________

# %%
# train the model using the Adam optimizer
print("[INFO] training network...")
opt = Adam(lr=1e-3, decay=1e-3)
model.compile(loss="categorical_crossentropy", optimizer=opt,
	metrics=["accuracy"])
H = model.fit(trainX, trainY, validation_data=(testX, testY), epochs=50, batch_size=32)
# Out:
# [INFO] training network...
# Epoch 1/50
# WARNING:tensorflow:Model was constructed with shape (None, 12288) for input KerasTensor(type_spec=TensorSpec(shape=(None, 12288), dtype=tf.float32, name='flatten_5_input'), name='flatten_5_input', description="created by layer 'flatten_5_input'"), but it was called on an input with incompatible shape (None, 64, 64, 3).
# WARNING:tensorflow:Model was constructed with shape (None, 12288) for input KerasTensor(type_spec=TensorSpec(shape=(None, 12288), dtype=tf.float32, name='flatten_5_input'), name='flatten_5_input', description="created by layer 'flatten_5_input'"), but it was called on an input with incompatible shape (None, 64, 64, 3).
# 23/23 [==============================] - ETA: 0s - loss: 1.4957 - accuracy: 0.2930WARNING:tensorflow:Model was constructed with shape (None, 12288) for input KerasTensor(type_spec=TensorSpec(shape=(None, 12288), dtype=tf.float32, name='flatten_5_input'), name='flatten_5_input', description="created by layer 'flatten_5_input'"), but it was called on an input with incompatible shape (None, 64, 64, 3).
# 23/23 [==============================] - 1s 15ms/step - loss: 1.4917 - accuracy: 0.2932 - val_loss: 1.1023 - val_accuracy: 0.3460
# Epoch 2/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.1199 - accuracy: 0.3595 - val_loss: 1.0906 - val_accuracy: 0.3460
# Epoch 3/50
# 23/23 [==============================] - 0s 6ms/step - loss: 1.1313 - accuracy: 0.3434 - val_loss: 1.0925 - val_accuracy: 0.3460
# Epoch 4/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.0863 - accuracy: 0.3861 - val_loss: 1.0872 - val_accuracy: 0.3460
# Epoch 5/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.1004 - accuracy: 0.3992 - val_loss: 1.0354 - val_accuracy: 0.3586
# Epoch 6/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.0982 - accuracy: 0.4060 - val_loss: 1.0344 - val_accuracy: 0.4262
# Epoch 7/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.0592 - accuracy: 0.4004 - val_loss: 0.9693 - val_accuracy: 0.5485
# Epoch 8/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.0653 - accuracy: 0.4111 - val_loss: 0.9986 - val_accuracy: 0.5907
# Epoch 9/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.9844 - accuracy: 0.4642 - val_loss: 0.8631 - val_accuracy: 0.5865
# Epoch 10/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.9552 - accuracy: 0.5140 - val_loss: 0.9186 - val_accuracy: 0.4810
# Epoch 11/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.9948 - accuracy: 0.4809 - val_loss: 0.8119 - val_accuracy: 0.5696
# Epoch 12/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.8947 - accuracy: 0.5315 - val_loss: 0.8237 - val_accuracy: 0.6118
# Epoch 13/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.9004 - accuracy: 0.5647 - val_loss: 0.7478 - val_accuracy: 0.7131
# Epoch 14/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.9236 - accuracy: 0.5925 - val_loss: 0.7911 - val_accuracy: 0.6203
# Epoch 15/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.8217 - accuracy: 0.5831 - val_loss: 0.8349 - val_accuracy: 0.6034
# Epoch 16/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.7843 - accuracy: 0.6399 - val_loss: 0.7949 - val_accuracy: 0.5907
# Epoch 17/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.7811 - accuracy: 0.6198 - val_loss: 0.7517 - val_accuracy: 0.7511
# Epoch 18/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.7237 - accuracy: 0.6626 - val_loss: 0.7032 - val_accuracy: 0.6034
# Epoch 19/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.7284 - accuracy: 0.6443 - val_loss: 0.6558 - val_accuracy: 0.7553
# Epoch 20/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.8156 - accuracy: 0.6649 - val_loss: 0.7313 - val_accuracy: 0.6203
# Epoch 21/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.7041 - accuracy: 0.6886 - val_loss: 0.6878 - val_accuracy: 0.6287
# Epoch 22/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.7089 - accuracy: 0.6646 - val_loss: 0.6679 - val_accuracy: 0.7004
# Epoch 23/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6864 - accuracy: 0.6754 - val_loss: 0.7065 - val_accuracy: 0.6962
# Epoch 24/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6079 - accuracy: 0.7062 - val_loss: 0.6079 - val_accuracy: 0.7890
# Epoch 25/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6173 - accuracy: 0.7347 - val_loss: 0.6301 - val_accuracy: 0.7595
# Epoch 26/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6334 - accuracy: 0.7396 - val_loss: 0.5906 - val_accuracy: 0.7511
# Epoch 27/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5823 - accuracy: 0.7582 - val_loss: 0.6338 - val_accuracy: 0.7553
# Epoch 28/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.7646 - accuracy: 0.6934 - val_loss: 0.5807 - val_accuracy: 0.7722
# Epoch 29/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5694 - accuracy: 0.7741 - val_loss: 0.6086 - val_accuracy: 0.7468
# Epoch 30/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5809 - accuracy: 0.7600 - val_loss: 0.5425 - val_accuracy: 0.7806
# Epoch 31/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5293 - accuracy: 0.7869 - val_loss: 0.5857 - val_accuracy: 0.7679
# Epoch 32/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5250 - accuracy: 0.8195 - val_loss: 0.6220 - val_accuracy: 0.7595
# Epoch 33/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5759 - accuracy: 0.7552 - val_loss: 0.6808 - val_accuracy: 0.6624
# Epoch 34/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6586 - accuracy: 0.7021 - val_loss: 0.6043 - val_accuracy: 0.7300
# Epoch 35/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5445 - accuracy: 0.7881 - val_loss: 0.6080 - val_accuracy: 0.7637
# Epoch 36/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4990 - accuracy: 0.8209 - val_loss: 0.5961 - val_accuracy: 0.7637
# Epoch 37/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5069 - accuracy: 0.8019 - val_loss: 0.6080 - val_accuracy: 0.7595
# Epoch 38/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5228 - accuracy: 0.8068 - val_loss: 0.6129 - val_accuracy: 0.7848
# Epoch 39/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4775 - accuracy: 0.7999 - val_loss: 0.6225 - val_accuracy: 0.8017
# Epoch 40/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4677 - accuracy: 0.7933 - val_loss: 0.6099 - val_accuracy: 0.7806
# Epoch 41/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4503 - accuracy: 0.8095 - val_loss: 0.6749 - val_accuracy: 0.7764
# Epoch 42/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4581 - accuracy: 0.7991 - val_loss: 0.7271 - val_accuracy: 0.7384
# Epoch 43/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4791 - accuracy: 0.8213 - val_loss: 0.6166 - val_accuracy: 0.7764
# Epoch 44/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4440 - accuracy: 0.8319 - val_loss: 0.5948 - val_accuracy: 0.7890
# Epoch 45/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4593 - accuracy: 0.8336 - val_loss: 0.6490 - val_accuracy: 0.7426
# Epoch 46/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4498 - accuracy: 0.8107 - val_loss: 0.5969 - val_accuracy: 0.7764
# Epoch 47/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.4368 - accuracy: 0.8187 - val_loss: 0.5865 - val_accuracy: 0.7975
# Epoch 48/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5054 - accuracy: 0.8016 - val_loss: 0.5982 - val_accuracy: 0.7764
# Epoch 49/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4117 - accuracy: 0.8589 - val_loss: 0.6384 - val_accuracy: 0.7932
# Epoch 50/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3879 - accuracy: 0.8768 - val_loss: 0.6504 - val_accuracy: 0.7806

# %%
import matplotlib.pyplot as plt

print(H.history.keys())
# summarize history for accuracy
plt.plot(H.history['accuracy'])
plt.plot(H.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(H.history['loss'])
plt.plot(H.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# evaluate the network
print("[INFO] evaluating network...")
predictions = model.predict(testX, batch_size=32)
print(classification_report(testY.argmax(axis=1),
	predictions.argmax(axis=1), target_names=lb.classes_))
# Out:
# [INFO] evaluating network...
# WARNING:tensorflow:Model was constructed with shape (None, 12288) for input KerasTensor(type_spec=TensorSpec(shape=(None, 12288), dtype=tf.float32, name='flatten_5_input'), name='flatten_5_input', description="created by layer 'flatten_5_input'"), but it was called on an input with incompatible shape (None, 64, 64, 3).
#               precision    recall  f1-score   support
#
#        coast       0.75      0.71      0.73        82
#       forest       0.92      0.78      0.84        89
#      highway       0.68      0.88      0.77        66
#
#     accuracy                           0.78       237
#    macro avg       0.79      0.79      0.78       237
# weighted avg       0.80      0.78      0.78       237

# %%
import cv2
import matplotlib.pyplot as plt

gambar = 'Forest_Test.jpg'
image = cv2.imread(gambar)
plt.imshow(image)
plt.show()

# %%
image_test=Image.open(gambar)
image_test=np.array(image_test.resize((64,64))) / 255.0
image_test.shape
# Out:
# (64, 64, 3)

# %%
image_test=np.expand_dims(image_test, axis=0)
image_test.shape
# Out:
# (1, 64, 64, 3)

# %%
predict = model.predict(image_test)

# %%
print(predict)
# Out:
# [[6.589947e-07 9.999993e-01 1.463303e-08]]

# %%
print(lb.classes_[predict.argmax(axis=1)])
# Out:
# ['forest']
